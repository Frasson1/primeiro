# %% [markdown]
# <a href="https://colab.research.google.com/github/Frasson1/primeiro/blob/main/mini_projeto_analise_de_dados_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Percorrer todos os arquivos da pasta base de dados (Vendas)

import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Python/Vendas-20240218T203144Z-001/Vendas")
display (lista_arquivo)

tabela_total = pd.DataFrame()

#Importar as bases de dados de vendas

for arquivo in lista_arquivo:
  if "Vendas" in arquivo:
    tabela = pd.read_csv(f"/content/drive/MyDrive/Curso Python/Vendas-20240218T203144Z-001/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)

#Tratar/compilar a base de dados
display(tabela_total)
# Out:
# ['Vendas - Rio de Janeiro.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - São Paulo.csv',
#  'Devolucoes - Recife.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Curitiba.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Salvador.csv',
#  'Vendas - Recife.csv',
#  'Devolucoes - Goiás.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Vendas - Curitiba.csv',
#  'Devolucoes - Belo Horizonte.csv']
# <ipython-input-67-4b64f924c7d5>:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-67-4b64f924c7d5>:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-67-4b64f924c7d5>:16: FutureWarning:
#
# ...

# %%
#Calcular a loja/cidade que mais vendeu (faturamento)
tabela_lojas = tabela_total.groupby("Loja").sum()
tabela_lojas = ["Faturamento"]
display(tabela_lojas)
# Out:
# <ipython-input-74-63ce7eee058a>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ['Faturamento']

# %%
import plotly.express as px
grafico = px.bar(tabela_lojas, x= tabela_lojas.index, y= 'Faturamento')
grafico.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-6cb1b5d5dd0e> in <cell line: 2>()
#       1 import plotly.express as px
# ----> 2 grafico = px.bar(tabela_lojas, x= tabela_lojas.index, y= 'Faturamento')
#       3 grafico.show()
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     371     mark.
# ...

# %%
#Calcular o produto que mais faturou (faturamento)
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[['Faturamento']].sort_values(by='Faturamento', ascending=True)
display(tabela_faturamento)
# Out:
# <ipython-input-70-50111b1b1d2e>:4: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#             Faturamento
# Produto
# SmartWatch      4172000
# Tablet          4673600
# Câmera          5890500
# Android        10822200
# Notebook       11371500
# Televisão      14827500
# iPhone         47562200

# %%
#Calcular o produto mais vendido (Quantidade)
tabela_produtos = tabela_total.groupby("Produto").sum()
tabela_produtos = tabela_produtos[['Quantidade Vendida']].sort_values(by='Quantidade Vendida', ascending=False)
display(tabela_produtos)
# Out:
# <ipython-input-71-0faaab4ebddb>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805
